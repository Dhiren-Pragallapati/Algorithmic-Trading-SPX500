# %%
import pandas as pd
import yfinance as yf
import numpy as np
import datetime
import matplotlib.pyplot as plt
from scipy import stats
import datetime
import time
import warnings

# %%
fin_metrics_path = '/Users/dhiren/Documents/University of Massachusetts Boston/Studies/Industry Practicum/Data/Financial Analysis 5.xlsx'
econ_indicators = '/Users/dhiren/Documents/University of Massachusetts Boston/Studies/Industry Practicum/Data/Economic Indicators (Historical 4 year data).xlsx'

# %%
try:
    all_sectors_data = pd.read_excel(fin_metrics_path, sheet_name=None)
except FileNotFoundError:
    print("The specified file was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# all sectors together
# Printing the first 5 rows of each sector to verify
for sector, data in all_sectors_data.items():
    print(f"First 5 rows of data for sector: {sector}")
    print(data.head(), "\n")

# %%
# Getting sector data seperately
print("Available Sectors:")
for sector in all_sectors_data.keys():
    print(sector)

# Interactive part to view specific sector data
while True:
    sector_input = input("Enter a sector name to view its data or type 'exit' to quit: ").strip()

    if sector_input.lower() == 'exit':
        break

    if sector_input in all_sectors_data:
        print(f"Data for sector: {sector_input}")
        print(all_sectors_data[sector_input].head())  # Display the first 5 rows of the sector
    else:
        print("Sector not found. Please enter a valid sector name.")

# %%
for sector, data in all_sectors_data.items():
    print(f"Column names for sector: {sector}")
    print(data.columns.tolist())  # I Converted Index object to a list using .tolist better readability
    print("\n")

# %%
# Preprocessed data
for sector, data in all_sectors_data.items():
    print(f"Processing sector: {sector}")
    
        
    # Replace common placeholders with NaN
    data.replace(['--', 'NA', '-'], pd.NA, inplace=True)
   
    # Replace '\n' in column names with a space
    data.columns = data.columns.str.replace('\n', ' ', regex=False)
    
    # Count and display missing values before preprocessing
    print("Missing values before preprocessing:")
    print(count_missing_values(data))
    print("\n")

# %%
# Processing data
# removed unwanted variables. changed data to numerics, dropped missing values
essential_columns = ['Revenue Growth', 'Debt/Equity', 'Earnings Growth', 
                     'P/B', 'P/E', 'Profit Margin', 'ROE', 'Dividend Yield']

for sector, data in all_sectors_data.items():
    print(f"Preprocessing data for sector: {sector}")

    # Handling missing values
    data.dropna(subset=essential_columns, inplace=True)
    
    # Remove unwanted columns
    removed_columns = ['Weight', 'Subgroup', 'Subgroup Weight', 'Shares']
    data.drop(columns=removed_columns, errors='ignore', inplace=True)

    # Ensure correct data types: Convert financial metrics to numeric
    data[essential_columns] = data[essential_columns].apply(pd.to_numeric, errors='coerce')

    # Store the processed data back into the main dictionary
    all_sectors_data[sector] = data

    # Display the processed data to confirm changes
    print("Missing values after preprocessing:")
    print(count_missing_values(data))
    print("\n")

# %%
def extract_ticker(name):
    # Split the string by space and take the first part
    return name.split()[0]

# Assuming all_sectors_data is your dictionary of DataFrames for each sector
for sector, data in all_sectors_data.items():
    print(f"Extracting tickers for sector: {sector}")

    # Check if the 'Ticker Name' column exists in the DataFrame
    if 'Ticker' in data.columns:
        # Apply the function to extract ticker symbols
        data['Ticker'] = data['Ticker'].apply(extract_ticker)
    else:
        print(f"No 'Ticker Name' column found in sector: {sector}")

    # Optionally, display the first few rows to verify
    print(data.head())

    # Update the DataFrame in the dictionary
    all_sectors_data[sector] = data

# %%
import pandas as pd

# Assuming all_sectors_data is the dictionary with processed data from Step 2

# Metrics for which we need sector averages
metrics_for_averages = ['Revenue Growth', 'Debt/Equity', 'Earnings Growth', 
                        'P/B', 'P/E', 'Profit Margin', 'ROE', 'Dividend Yield']

# Dictionary to store sector averages
sector_averages = {}

# Calculate averages for each sector
for sector, data in all_sectors_data.items():
    print(f"Calculating averages for sector: {sector}")

    # Initialize a dictionary to store averages for the current sector
    sector_averages[sector] = {}

    for metric in metrics_for_averages:
        if metric in data.columns:
            # Calculate the mean for each metric, ignoring NaN values
            average_value = data[metric].mean(skipna=True)
            sector_averages[sector][metric] = average_value
    
    # Print sector averages for verification
    print(f"Sector Averages for {sector}:")
    for metric, avg in sector_averages[sector].items():
        print(f"{metric}: {avg}")
    print("\n")  # New line for readability

# Optionally, convert the dictionary to a DataFrame for easier handling
sector_averages_df = pd.DataFrame(sector_averages).T

# %%
# Function to display investment strategy options and capture user selection
def select_investment_strategy():
    print("Select an Investment Strategy:")
    print("1. Peter Lynch's 'Fast Growers' Strategy")
    print("2. Philip Fisher's Quality Growth Strategy")
    print("3. Warren Buffett's Value Investing")
    print("4. Benjamin Graham's Defensive Investing")

    # User input for strategy selection
    while True:
        user_choice = input("Enter the number of your chosen strategy (or 'exit' to quit): ")

        # Dictionary mapping strategies to their respective criteria identifiers
        strategy_map = {
            '1': "Peter Lynch",
            '2': "Philip Fisher",
            '3': "Warren Buffett",
            '4': "Benjamin Graham"
        }

        # Handle user choice
        if user_choice.lower() == 'exit':
            print("Exiting the strategy selection.")
            return None
        elif user_choice in strategy_map:
            selected_strategy = strategy_map[user_choice]
            print(f"You have selected: {selected_strategy}")
            return selected_strategy
        else:
            print("Invalid selection. Please enter a valid number.")

# Call the function and store the selected strategy
selected_strategy = select_investment_strategy()

# Proceed based on the selected strategy
if selected_strategy:
    # Subsequent filtering will be based on this choice
    print(f"Proceeding with the {selected_strategy} strategy...")
    # Filtering logic will be implemented in the next steps
else:
    # Handle the case where no valid strategy was selected
    print("No valid investment strategy selected.")

# %%
#Filtering Stocks Based on Strategy

def filter_for_peter_lynch(data, averages):
    return data[
        (data['Revenue Growth'] > averages['Revenue Growth']) &
        (data['Earnings Growth'] > averages['Earnings Growth']) &
        (data['P/E'] < averages['P/E'])
    ]

def filter_for_philip_fisher(data, averages):
    return data[
        (data['Revenue Growth'] > averages['Revenue Growth']) &
        (data['Earnings Growth'] > averages['Earnings Growth']) &
        (data['ROE'] > averages['ROE']) &
        (data['P/B'] < averages['P/B'])
    ]

def filter_for_warren_buffett(data, averages):
    return data[
        (data['P/E'] < averages['P/E']) &
        (data['ROE'] > averages['ROE']) &
        (data['Debt/Equity'] < averages['Debt/Equity']) &
        (data['Profit Margin'] > averages['Profit Margin'])
    ]

def filter_for_benjamin_graham(data, averages):
    return data[
        (data['P/E'] < averages['P/E']) &
        (data['P/B'] < averages['P/B']) &
        # Assuming Dividend Yield data is available and calculated
        (data['Dividend Yield'] > averages['Dividend Yield']) &
        (data['Debt/Equity'] < averages['Debt/Equity'])
    ]

# %%
# Map strategy names to their respective filter functions
strategy_filter_functions = {
    'Peter Lynch': filter_for_peter_lynch,
    'Philip Fisher': filter_for_philip_fisher,
    'Warren Buffett': filter_for_warren_buffett,
    'Benjamin Graham': filter_for_benjamin_graham
}

filtered_stocks = {}  # Dictionary to store the filtered stocks by sector

if selected_strategy in strategy_filter_functions:
    filter_function = strategy_filter_functions[selected_strategy]

    # Apply the filter to each sector's data
    for sector, data in all_sectors_data.items():
        averages = sector_averages_df.loc[sector]
        filtered_data = filter_function(data, averages)
        filtered_stocks[sector] = filtered_data

        # Optional: Display the filtered data
        print(f"Filtered data for sector {sector} using {selected_strategy} strategy:")
        print(filtered_data.head())  # Display the first few rows of the filtered data
        print("\n")
else:
    print("No valid strategy selected for filtering.")

# %%
print("Number of companies in each sector before filtering:")

for sector, data in all_sectors_data.items():
    total_companies_before = len(data)
    print(f"{sector}: {total_companies_before} companies")

# %%
print("Number of companies in each sector after filtering:")

for sector, filtered_data in filtered_stocks.items():
    total_companies_after = len(filtered_data)
    print(f"{sector}: {total_companies_after} companies")

# %%
# Function to display the final list of filtered stocks sector-wise
def display_filtered_stocks_sector_wise(filtered_stocks):
    for sector, stocks in filtered_stocks.items():
        print(f"Filtered stocks in sector: {sector}")
        if not stocks.empty:
            print(stocks)
        else:
            print("No stocks met the criteria in this sector.")
        print("\n")  # New line for better readability

    # Optional: Save the final list to a CSV file
    save_choice = input("Do you want to save the final list to a CSV file? (yes/no): ").lower()
    if save_choice == 'yes':
        combined_filtered_stocks = pd.concat(filtered_stocks.values(), ignore_index=True)
        combined_filtered_stocks.to_csv('Filtered_Stocks_Sector_Wise.csv', index=False)
        print("Filtered stocks saved to 'Filtered_Stocks_Sector_Wise.csv'.")
    else:
        print("Final list not saved.")

# Assuming 'filtered_stocks' is the dictionary containing the filtered data from Step 5
display_filtered_stocks_sector_wise(filtered_stocks)

# %%
def plot_filtered_stocks_vs_index(filtered_stocks, index_ticker):
    # Define the time period for historical data
    end_date = datetime.date(2023, 12, 31)  # Last day of 2023
    start_date = end_date - datetime.timedelta(days=8*365)  # 8 years back from end date
    
    # Extract all unique tickers from the filtered stocks
    all_filtered_tickers = set()
    for sector_data in filtered_stocks.values():
        if not sector_data.empty and 'Ticker' in sector_data.columns:
            tickers = sector_data['Ticker'].unique()
            all_filtered_tickers.update(tickers)
    
    # Convert set to list for data download
    filtered_stock_list = list(all_filtered_tickers)
    
    # Suppress specific warnings from yfinance
    warnings.filterwarnings("ignore", category=FutureWarning)
    
    print(f"Attempting to download data for {len(filtered_stock_list)} stocks plus index...")
    
    # Initialize historical data DataFrame
    historical_data = pd.DataFrame()
    failed_downloads = []
    
    # Use batch download instead of individual downloads
    # yfinance can download multiple tickers at once, reducing API calls
    all_tickers = filtered_stock_list + [index_ticker]
    
    try:
        # First, try downloading all tickers in a single batch
        print("Attempting batch download of all tickers...")
        batch_data = yf.download(
            all_tickers,
            start=start_date,
            end=end_date,
            progress=False,
            group_by='ticker',
            auto_adjust=True,
            threads=True
        )
        
        # Process the batch data if successful
        if not batch_data.empty:
            # For single ticker, structure will be different
            if len(all_tickers) == 1:
                ticker = all_tickers[0]
                historical_data[ticker] = batch_data['Close']
            else:
                # Extract 'Close' prices for each ticker
                for ticker in all_tickers:
                    if (ticker, 'Close') in batch_data.columns:
                        historical_data[ticker] = batch_data[(ticker, 'Close')]
                    else:
                        failed_downloads.append(ticker)
        
        # If batch download failed or missed some tickers, going to try individual downloads
        if historical_data.empty or len(failed_downloads) > 0:
            print("Batch download incomplete. Trying individual downloads for missing tickers...")
            
            # If batch download completely failed, reset the failed downloads list
            if historical_data.empty:
                failed_downloads = all_tickers
            
            # Try downloading each failed ticker individually
            for ticker in failed_downloads[:]:  # Use a copy to allow modification during iteration
                try:
                    print(f"Attempting to download {ticker}...")
                    stock_data = yf.download(
                        ticker,
                        start=start_date,
                        end=end_date,
                        progress=False,
                        auto_adjust=True
                    )
                    
                    if not stock_data.empty and 'Close' in stock_data.columns:
                        historical_data[ticker] = stock_data['Close']
                        failed_downloads.remove(ticker)
                        print(f"Successfully downloaded {ticker}")
                    else:
                        print(f"No data available for {ticker}")
                        
                except Exception as e:
                    print(f"Error downloading {ticker}: {e}")
                    
                # Add a delay between requests
                time.sleep(1)
        
        # Report on download results
        print(f"Successfully downloaded {len(historical_data.columns)} out of {len(all_tickers)} tickers")
        if failed_downloads:
            print(f"Failed to download {len(failed_downloads)} tickers: {failed_downloads}")
        
        if historical_data.empty:
            print("No data available for plotting.")
            return
        
        # Sort the index to ensure chronological order
        historical_data.sort_index(inplace=True)
        
        # Handle missing values
        historical_data = historical_data.fillna(method='ffill').fillna(method='bfill')
        
        # Check if we have enough data to plot
        if len(historical_data.columns) < 1:
            print("Not enough data for plotting.")
            return
            
        # Normalize data to compare performance
        normalized_data = historical_data.div(historical_data.iloc[0])
        
        # Plotting
        plt.figure(figsize=(15, 8))
        
        # Plot each filtered stock
        for stock in filtered_stock_list:
            if stock in normalized_data.columns:
                plt.plot(normalized_data[stock], label=stock, alpha=0.7)
        
        # Plot the index for comparison
        if index_ticker in normalized_data.columns:
            plt.plot(normalized_data[index_ticker], label='S&P 500 Index', linestyle='-', linewidth=2.5, color='black')
        
        # Formatting the plot
        plt.title('Filtered Stocks Performance vs. S&P 500 Index (Through 2023)')
        plt.xlabel('Date')
        plt.ylabel('Normalized Price')
        plt.grid(True, linestyle='--', alpha=0.7)
        
        # Set the x-axis limits
        plt.xlim(pd.Timestamp(start_date), pd.Timestamp('2023-12-31'))
        
        # Repositioning the legend
        plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5, fontsize=8)
        
        plt.tight_layout()
        plt.show()
        print("Plot displayed successfully")
    
    except Exception as e:
        print(f"Error during processing or plotting: {e}")
        import traceback
        traceback.print_exc()

# Extract all unique tickers from the filtered stocks
all_filtered_tickers = set()
for sector_data in filtered_stocks.values():
    if not sector_data.empty and 'Ticker' in sector_data.columns:
        tickers = sector_data['Ticker'].unique()
        all_filtered_tickers.update(tickers)

# Convert set to list for data download
filtered_stock_list = list(all_filtered_tickers)
print(f"Found {len(filtered_stock_list)} filtered stocks to plot")

# Plotting the performance of these stocks against the S&P 500 Index
plot_filtered_stocks_vs_index(filtered_stocks, index_ticker='^GSPC')

# %%
def plot_sector_performance(filtered_stocks_by_sector, index_ticker):
    # Define the time period for historical data
    end_date = datetime.date(2023, 12, 31)  # Last day of 2023
    start_date = end_date - datetime.timedelta(days=8*365)  # Last 8 years
    
    # Import yfinance
    import yfinance as yf
    import warnings
    
    # Suppress specific warnings from yfinance
    warnings.filterwarnings("ignore", category=FutureWarning)
    
    for sector, stocks_df in filtered_stocks_by_sector.items():
        if stocks_df.empty:
            print(f"No filtered stocks to display for sector: {sector}")
            continue
        
        stock_list = stocks_df['Ticker'].unique().tolist()
        print(f"Processing sector {sector} with {len(stock_list)} stocks")
        
        try:
            # Initialize historical data DataFrame
            historical_data = pd.DataFrame()
            
            # Add the S&P 500 index to the list of tickers to download
            all_tickers = stock_list + [index_ticker]
            
            # Try batch download first (more efficient)
            print(f"Attempting batch download for {sector} sector...")
            batch_data = yf.download(
                all_tickers,
                start=start_date,
                end=end_date,
                progress=False,
                group_by='ticker',
                auto_adjust=True,
                threads=True
            )
            
            # Process the batch data if successful
            if not batch_data.empty:
                # For single ticker, structure will be different
                if len(all_tickers) == 1:
                    ticker = all_tickers[0]
                    historical_data[ticker] = batch_data['Close']
                else:
                    # Extract 'Close' prices for each ticker
                    for ticker in all_tickers:
                        if (ticker, 'Close') in batch_data.columns:
                            historical_data[ticker] = batch_data[(ticker, 'Close')]
            
            # If batch download failed or some tickers are missing, try individual downloads
            failed_tickers = [ticker for ticker in all_tickers if ticker not in historical_data.columns]
            
            if failed_tickers:
                print(f"Batch download incomplete for {sector}. Trying individual downloads for {len(failed_tickers)} tickers...")
                
                for ticker in failed_tickers:
                    try:
                        print(f"Attempting to download {ticker}...")
                        stock_data = yf.download(
                            ticker,
                            start=start_date,
                            end=end_date,
                            progress=False,
                            auto_adjust=True
                        )
                        
                        if not stock_data.empty and 'Close' in stock_data.columns:
                            historical_data[ticker] = stock_data['Close']
                            print(f"Successfully downloaded {ticker}")
                        else:
                            print(f"No data available for {ticker}")
                            
                    except Exception as e:
                        print(f"Error downloading {ticker}: {e}")
                        
                    # Add a delay between requests
                    time.sleep(1)
            
            if historical_data.empty:
                print(f"No data available for plotting sector: {sector}")
                continue
                
            # Ensure data is sorted chronologically
            historical_data.sort_index(inplace=True)
            
            # Explicitly filter data to ensure it doesn't go beyond end_date
            cutoff_date = pd.Timestamp('2023-12-31')
            historical_data = historical_data[historical_data.index <= cutoff_date]
            
            # Handle missing values
            historical_data = historical_data.fillna(method='ffill').fillna(method='bfill')
            
            # Check if we have enough data to plot
            if len(historical_data.columns) < 1:
                print(f"Not enough data for plotting sector: {sector}")
                continue
                
            # Normalize data to compare performance
            normalized_data = historical_data.div(historical_data.iloc[0])
            
            # Plotting
            plt.figure(figsize=(15, 8))
            
            # Plot each filtered stock
            for stock in stock_list:
                if stock in normalized_data.columns:
                    plt.plot(normalized_data[stock], label=stock, alpha=0.7)
            
            # Plot the index for comparison
            if index_ticker in normalized_data.columns:
                plt.plot(normalized_data[index_ticker], label='S&P 500 Index', 
                         linestyle='-', linewidth=2.5, color='black')
            
            # Formatting the plot
            plt.title(f'{sector} Sector Performance vs. S&P 500 Index (Through 2023)')
            plt.xlabel('Date')
            plt.ylabel('Normalized Price')
            plt.grid(True, linestyle='--', alpha=0.7)
            
            # Set the x-axis limits explicitly
            plt.xlim(pd.Timestamp(start_date), pd.Timestamp('2023-12-31'))
            
            # Repositioning the legend
            plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), 
                      ncol=min(5, len(stock_list) + 1), fontsize=8)
            
            plt.tight_layout()
            plt.show()
            print(f"Plot displayed successfully for {sector} sector")
            
        except Exception as e:
            print(f"An error occurred while processing data for sector: {sector}. Error: {e}")
            import traceback
            traceback.print_exc()

# Call the function with the filtered stocks and the S&P 500 index
plot_sector_performance(filtered_stocks, index_ticker='^GSPC')

# %%
def fetch_historical_data(stock_list, start_date, end_date):
    """
    Fetches historical closing prices for a list of stocks using yfinance.
    :param stock_list: List of stock tickers
    :param start_date: Start date for historical data
    :param end_date: End date for historical data
    :return: DataFrame with historical data
    """
    import yfinance as yf
    import warnings
    import time
    
    # Suppress specific warnings from yfinance
    warnings.filterwarnings("ignore", category=FutureWarning)
    
    historical_data = pd.DataFrame()
    failed_tickers = []
    
    print(f"Attempting to download data for {len(stock_list)} stocks...")
    
    # Try batch download first (more efficient)
    try:
        print("Attempting batch download of all tickers...")
        batch_data = yf.download(
            stock_list,
            start=start_date,
            end=end_date,
            progress=False,
            group_by='ticker',
            auto_adjust=True,
            threads=True
        )
        
        # Process the batch data if successful
        if not batch_data.empty:
            # For single ticker, structure will be different
            if len(stock_list) == 1:
                ticker = stock_list[0]
                if 'Close' in batch_data.columns:
                    # Initialize the DataFrame with the first ticker
                    historical_data = pd.DataFrame(index=batch_data.index)
                    historical_data[ticker] = batch_data['Close']
                    print(f"Successfully downloaded data for {ticker}")
                else:
                    failed_tickers.append(ticker)
            else:
                # Initialize the DataFrame with the batch data index
                historical_data = pd.DataFrame(index=batch_data.index.unique())
                
                # Extract 'Close' prices for each ticker
                for ticker in stock_list:
                    if (ticker, 'Close') in batch_data.columns:
                        historical_data[ticker] = batch_data[(ticker, 'Close')]
                        print(f"Successfully downloaded data for {ticker}")
                    else:
                        failed_tickers.append(ticker)
                        print(f"No Close data available for {ticker} in batch download")
    except Exception as e:
        print(f"Batch download failed: {e}")
        failed_tickers = stock_list
    
    # If batch download failed or some tickers are missing, try individual downloads
    if historical_data.empty or failed_tickers:
        print(f"Batch download incomplete. Trying individual downloads for {len(failed_tickers)} tickers...")
        
        for ticker in failed_tickers:
            try:
                print(f"Attempting to download {ticker}...")
                stock_data = yf.download(
                    ticker,
                    start=start_date,
                    end=end_date,
                    progress=False,
                    auto_adjust=True
                )
                
                # Sort the index to ensure chronological order (oldest to newest)
                stock_data = stock_data.sort_index()
                
                if not stock_data.empty and 'Close' in stock_data.columns:
                    # If this is the first ticker, initialize the DataFrame
                    if historical_data.empty:
                        historical_data = pd.DataFrame(index=stock_data.index)
                    # Add the Close price for this ticker
                    historical_data[ticker] = stock_data['Close']
                    print(f"Successfully downloaded data for {ticker}")
                else:
                    print(f"No Close data available for {ticker}")
                    
            except Exception as e:
                print(f"Error downloading {ticker}: {e}")
                
            # Add a delay between requests
            time.sleep(1)
    
    # Ensure the entire dataframe is sorted chronologically
    historical_data = historical_data.sort_index()
    
    # Fill missing dates with forward fill then backward fill
    historical_data = historical_data.fillna(method='ffill').fillna(method='bfill')
    
    # Report download statistics
    print(f"Successfully downloaded data for {len(historical_data.columns)} out of {len(stock_list)} stocks")
    
    return historical_data

# Define the historical range for backtesting (last 8 years through end of 2023)
end_date = datetime.date(2023, 12, 31)  # Last day of 2023
start_date = end_date - datetime.timedelta(days=8*365)  # Last 8 years

# Extract all unique tickers from the filtered stocks
all_filtered_tickers = set()
for sector_data in filtered_stocks.values():
    tickers = sector_data['Ticker'].unique()  # Assuming 'Ticker' column contains stock tickers
    all_filtered_tickers.update(tickers)

# Convert set to list for data download
filtered_stock_list = list(all_filtered_tickers)

# Fetch historical data
historical_stock_data = fetch_historical_data(filtered_stock_list, start_date, end_date)

# Display the first few rows of the fetched data
print(historical_stock_data.head())

# %%
# Update the calculate_daily_returns function with the improved version
def calculate_daily_returns(historical_data):
    """
    Calculates daily returns from historical stock prices in percentage.
    :param historical_data: DataFrame with historical stock prices
    :return: DataFrame with daily returns in percentage
    """
    # First check if there are any missing values in the historical data
    if historical_data.isna().any().any():
        print("Warning: Historical data contains missing values. Filling with forward and backward fill.")
        historical_data = historical_data.fillna(method='ffill').fillna(method='bfill')
    
    # Calculate percentage change
    daily_returns = historical_data.pct_change()
    
    # Drop rows that are all NaN (like the first row which will be all NaN after pct_change)
    daily_returns = daily_returns.dropna(how='all')
    
    # Check if we have any returns
    if daily_returns.empty:
        print("Error: No valid returns calculated. Check historical data.")
    else:
        print(f"Successfully calculated returns for {len(daily_returns)} days")
    
    return daily_returns

# Apply the updated function to your historical data
daily_returns_filtered_stocks = calculate_daily_returns(historical_stock_data)

# Display the first few rows of the daily returns in percentage
print(daily_returns_filtered_stocks.head())

# %%
market_caps = pd.DataFrame()

for sector_data in filtered_stocks.values():
    market_caps = pd.concat([market_caps, sector_data[['Ticker', 'Market Cap']]])


market_caps.set_index('Ticker', inplace=True)

def calculate_portfolio_weights(market_caps):
    total_market_cap = market_caps['Market Cap'].sum()
    weights = market_caps['Market Cap'] / total_market_cap
    return weights

# Calculate the weights
weights = calculate_portfolio_weights(market_caps)

def simulate_value_weighted_portfolio(daily_returns, weights):
    weighted_returns = daily_returns.multiply(weights, axis='columns')
    portfolio_returns = weighted_returns.sum(axis=1)
    return portfolio_returns


aligned_daily_returns = daily_returns_filtered_stocks[weights.index]


value_weighted_portfolio_returns = simulate_value_weighted_portfolio(aligned_daily_returns, weights)

# Display the first few rows of the portfolio returns
print(value_weighted_portfolio_returns.head())

daily_returns_filtered_stocks = daily_returns_filtered_stocks.apply(pd.to_numeric, errors='coerce')
weights = weights.apply(pd.to_numeric, errors='coerce')

# %%
def fetch_benchmark_data(benchmark_ticker, start_date, end_date):
    """
    Fetches historical data for a benchmark index using yfinance.
    :param benchmark_ticker: Ticker symbol for the benchmark
    :param start_date: Start date for historical data
    :param end_date: End date for historical data
    :return: Series with benchmark closing prices
    """
    import yfinance as yf
    import warnings
    
    # Suppress specific warnings from yfinance
    warnings.filterwarnings("ignore", category=FutureWarning)
    
    try:
        print(f"Attempting to download benchmark data for {benchmark_ticker}...")
        benchmark_data = yf.download(
            benchmark_ticker, 
            start=start_date,
            end=end_date,
            progress=False,
            auto_adjust=True
        )
        
        if not benchmark_data.empty and 'Close' in benchmark_data.columns:
            print(f"Successfully downloaded benchmark data for {benchmark_ticker}")
            return benchmark_data['Close']
        else:
            print(f"No Close data available for benchmark {benchmark_ticker}")
            return pd.Series()
            
    except Exception as e:
        print(f"Error downloading benchmark data for {benchmark_ticker}: {e}")
        return pd.Series()

def calculate_total_and_annualized_returns(daily_returns):
    """
    Calculates total and annualized returns from daily returns.
    :param daily_returns: Series with daily returns
    :return: Total return and annualized return
    """
    # Convert to numpy array if it's a Series
    if isinstance(daily_returns, pd.Series):
        daily_values = daily_returns.values
    else:
        daily_values = daily_returns
        
    # Calculate total return
    total_return = float(np.prod(1 + daily_values) - 1)
    
    # Calculate annualized return
    n_days = len(daily_values)
    annualized_return = float((1 + total_return) ** (365 / n_days) - 1)
    
    return total_return, annualized_return

# Define the date range (8 years through end of 2023)
end_date = datetime.date(2023, 12, 31)  # Last day of 2023
start_date = end_date - datetime.timedelta(days=8*365)  # Last 8 years

# Fetch benchmark data
benchmark_ticker = '^GSPC'  # S&P 500
benchmark_data = fetch_benchmark_data(benchmark_ticker, start_date, end_date)

# Make sure benchmark_data has values before proceeding
if len(benchmark_data) > 0:
    # Calculate benchmark returns
    benchmark_returns = benchmark_data.pct_change().dropna()
    
    # For demonstration, assuming value_weighted_portfolio_returns exists
    # If not, use benchmark returns as placeholder
    if 'value_weighted_portfolio_returns' not in globals():
        print("Warning: value_weighted_portfolio_returns not defined. Using benchmark returns as placeholder.")
        value_weighted_portfolio_returns = benchmark_returns
    
    # Calculate total and annualized returns
    portfolio_total_return, portfolio_annualized_return = calculate_total_and_annualized_returns(value_weighted_portfolio_returns)
    benchmark_total_return, benchmark_annualized_return = calculate_total_and_annualized_returns(benchmark_returns)
    
    # Comparison - explicitly format as floats
    print("Portfolio vs. Benchmark Performance:")
    print(f"Portfolio Total Return: {portfolio_total_return:.2%}")
    print(f"Portfolio Annualized Return: {portfolio_annualized_return:.2%}")
    print(f"Benchmark Total Return: {benchmark_total_return:.2%}")
    print(f"Benchmark Annualized Return: {benchmark_annualized_return:.2%}")
else:
    print("Unable to fetch benchmark data. Please check the ticker symbol or try again later.")

# %%
def calculate_standard_deviation(returns):
    """
    Calculates the standard deviation (volatility) of returns.
    :param returns: Series with returns
    :return: Standard deviation
    """
    # Ensure we're working with numpy values if it's a Series
    if isinstance(returns, pd.Series):
        return float(returns.std() * (252 ** 0.5))  # Annualized volatility
    else:
        return float(np.std(returns) * (252 ** 0.5))

def calculate_beta(portfolio_returns, benchmark_returns):
    """
    Calculates the beta of portfolio returns against benchmark returns.
    :param portfolio_returns: Series with portfolio returns
    :param benchmark_returns: Series with benchmark returns
    :return: Beta value
    """
    # Align the data to ensure we're comparing returns from the same dates
    aligned_data = pd.concat([portfolio_returns, benchmark_returns], axis=1, join='inner').dropna()
    portfolio_returns_aligned = aligned_data.iloc[:, 0]
    benchmark_returns_aligned = aligned_data.iloc[:, 1]
    
    # Calculate beta using covariance and variance
    mean_portfolio_return = portfolio_returns_aligned.mean()
    mean_benchmark_return = benchmark_returns_aligned.mean()
    covariance = ((portfolio_returns_aligned - mean_portfolio_return) * 
                 (benchmark_returns_aligned - mean_benchmark_return)).mean()
    variance = (benchmark_returns_aligned - mean_benchmark_return).var()
    
    # Calculate beta
    beta = covariance / variance
    return float(beta)  # Convert to float to ensure it's not a Series or array

def calculate_sharpe_ratio(portfolio_returns, risk_free_rate=0.01):
    """
    Calculates the Sharpe ratio for portfolio returns.
    :param portfolio_returns: Series with portfolio returns
    :param risk_free_rate: Annual risk-free rate (default: 1%)
    :return: Sharpe ratio
    """
    # Convert annual risk-free rate to daily
    daily_risk_free_rate = risk_free_rate / 252
    
    # Ensure we're working with numpy values if it's a Series
    if isinstance(portfolio_returns, pd.Series):
        # Calculate excess returns and Sharpe ratio
        excess_returns = portfolio_returns - daily_risk_free_rate
        annualized_excess_return = excess_returns.mean() * 252
        annualized_volatility = excess_returns.std() * (252 ** 0.5)
    else:
        # Calculate with numpy arrays
        excess_returns = portfolio_returns - daily_risk_free_rate
        annualized_excess_return = np.mean(excess_returns) * 252
        annualized_volatility = np.std(excess_returns) * (252 ** 0.5)
    
    # Return as float to ensure it's not a Series or array
    return float(annualized_excess_return / annualized_volatility)

# Define the date range (8 years through end of 2023)
end_date = datetime.date(2023, 12, 31)  # Last day of 2023
start_date = end_date - datetime.timedelta(days=8*365)  # Last 8 years

# Fetch benchmark data
benchmark_ticker = '^GSPC'  # S&P 500
benchmark_data = fetch_benchmark_data(benchmark_ticker, start_date, end_date)

# Make sure benchmark_data has values before proceeding
if len(benchmark_data) > 0:
    # Calculate benchmark returns
    benchmark_returns = benchmark_data.pct_change().dropna()
    
    # For demonstration, assuming value_weighted_portfolio_returns exists
    # If not, use benchmark returns as placeholder
    if 'value_weighted_portfolio_returns' not in globals():
        print("Warning: value_weighted_portfolio_returns not defined. Using benchmark returns as placeholder.")
        value_weighted_portfolio_returns = benchmark_returns
    
    # Calculate total and annualized returns
    portfolio_total_return, portfolio_annualized_return = calculate_total_and_annualized_returns(value_weighted_portfolio_returns)
    benchmark_total_return, benchmark_annualized_return = calculate_total_and_annualized_returns(benchmark_returns)
     
    # Calculate risk metrics
    portfolio_volatility = calculate_standard_deviation(value_weighted_portfolio_returns)
    benchmark_volatility = calculate_standard_deviation(benchmark_returns)
    portfolio_beta = calculate_beta(value_weighted_portfolio_returns, benchmark_returns)
    portfolio_sharpe_ratio = calculate_sharpe_ratio(value_weighted_portfolio_returns)
    
    # Display risk metrics
    print("\nRisk Metrics:")
    print(f"Portfolio Volatility (Annualized): {portfolio_volatility:.2%}")
    print(f"Benchmark Volatility (Annualized): {benchmark_volatility:.2%}")
    print(f"Portfolio Beta: {portfolio_beta:.2f}")
    print(f"Portfolio Sharpe Ratio: {portfolio_sharpe_ratio:.2f}")
else:
    print("Unable to fetch benchmark data. Please check the ticker symbol or try again later.")

# %%
def plot_cumulative_returns(portfolio_returns, benchmark_returns, title="Cumulative Returns Through 2023"):
    """
    Plots the cumulative returns of the portfolio and benchmark.
    :param portfolio_returns: Series with portfolio returns
    :param benchmark_returns: Series with benchmark returns
    :param title: Plot title
    """
    # Align dates between portfolio and benchmark returns
    aligned_data = pd.concat([portfolio_returns, benchmark_returns], axis=1, join='inner').dropna()
    aligned_portfolio_returns = aligned_data.iloc[:, 0]
    aligned_benchmark_returns = aligned_data.iloc[:, 1]
    
    # Calculate cumulative returns
    cumulative_returns_portfolio = (1 + aligned_portfolio_returns).cumprod()
    cumulative_returns_benchmark = (1 + aligned_benchmark_returns).cumprod()
    
    # Plot
    plt.figure(figsize=(15, 8))
    plt.plot(cumulative_returns_portfolio, label='Value-Weighted Portfolio', linewidth=2)
    plt.plot(cumulative_returns_benchmark, label='S&P 500 Index', linewidth=2, color='black')
    plt.title(title, fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Cumulative Returns', fontsize=12)
    
    # Set explicit x-axis limits
    plt.xlim(cumulative_returns_portfolio.index.min(), pd.Timestamp('2023-12-31'))
    
    # Calculate final values
    portfolio_final = cumulative_returns_portfolio.iloc[-1]
    benchmark_final = cumulative_returns_benchmark.iloc[-1]
    
    # Annotate final values
    plt.annotate(f'Portfolio: {portfolio_final:.2f}x', 
                 xy=(cumulative_returns_portfolio.index[-1], portfolio_final),
                 xytext=(-100, 20), textcoords='offset points',
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'))
    
    plt.annotate(f'S&P 500: {benchmark_final:.2f}x', 
                 xy=(cumulative_returns_benchmark.index[-1], benchmark_final),
                 xytext=(-100, -30), textcoords='offset points',
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=-.2'))
    
    plt.legend(loc='upper left')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

def create_performance_summary(portfolio_returns, benchmark_returns):
    """
    Creates a comprehensive summary of key performance metrics.
    :param portfolio_returns: Series with portfolio returns
    :param benchmark_returns: Series with benchmark returns
    :return: Dictionary containing performance metrics
    """
    # Calculate return metrics
    portfolio_total_return, portfolio_annualized_return = calculate_total_and_annualized_returns(portfolio_returns)
    benchmark_total_return, benchmark_annualized_return = calculate_total_and_annualized_returns(benchmark_returns)
    
    # Calculate risk metrics
    portfolio_volatility = calculate_standard_deviation(portfolio_returns)
    benchmark_volatility = calculate_standard_deviation(benchmark_returns)
    portfolio_beta = calculate_beta(portfolio_returns, benchmark_returns)
    portfolio_sharpe_ratio = calculate_sharpe_ratio(portfolio_returns)
    
    # Calculate alpha
    portfolio_alpha = portfolio_annualized_return - (0.01 + portfolio_beta * (benchmark_annualized_return - 0.01))
    
    # Create summary dictionary
    summary = {
        'Portfolio Total Return': portfolio_total_return,
        'Benchmark Total Return': benchmark_total_return,
        'Portfolio Annualized Return': portfolio_annualized_return,
        'Benchmark Annualized Return': benchmark_annualized_return,
        'Portfolio Volatility (Annualized)': portfolio_volatility,
        'Benchmark Volatility (Annualized)': benchmark_volatility,
        'Portfolio Beta': portfolio_beta,
        'Portfolio Alpha': portfolio_alpha,
        'Portfolio Sharpe Ratio': portfolio_sharpe_ratio
    }
    
    return summary

# Align the portfolio and benchmark returns to ensure consistent date ranges
aligned_data = pd.concat([value_weighted_portfolio_returns, benchmark_returns], axis=1, 
                         join='inner').dropna()
aligned_portfolio_returns = aligned_data.iloc[:, 0]
aligned_benchmark_returns = aligned_data.iloc[:, 1]

# Plotting cumulative returns
plot_cumulative_returns(aligned_portfolio_returns, aligned_benchmark_returns)

# Creating a comprehensive performance summary
performance_summary = create_performance_summary(aligned_portfolio_returns, aligned_benchmark_returns)

# Display performance summary in a more readable format
print("Performance Summary (8-Year Period Through Dec 31, 2023):")
print("-" * 60)
print(f"{'Metric':<30} {'Portfolio':>12} {'Benchmark':>12}")
print("-" * 60)
print(f"{'Total Return':<30} {performance_summary['Portfolio Total Return']:>11.2%} {performance_summary['Benchmark Total Return']:>11.2%}")
print(f"{'Annualized Return':<30} {performance_summary['Portfolio Annualized Return']:>11.2%} {performance_summary['Benchmark Annualized Return']:>11.2%}")
print(f"{'Volatility (Annualized)':<30} {performance_summary['Portfolio Volatility (Annualized)']:>11.2%} {performance_summary['Benchmark Volatility (Annualized)']:>11.2%}")
print("-" * 60)
